# %%
count=1
while count<=5:
  print(count)
  count+=1
print("End of the program")
# Out:
# 1
# 2
# 3
# 4
# 5
# End of the program

# %%
water_level=20 #in percentage
while water_level<50:
   print("Irrigation ON - Water level:", water_level," % ")
   water_level+=5
print("Sufficient water.Irrigation OFF.")
# Out:
# Irrigation ON - Water level: 20  %
# Irrigation ON - Water level: 25  %
# Irrigation ON - Water level: 30  %
# Irrigation ON - Water level: 35  %
# Irrigation ON - Water level: 40  %
# Irrigation ON - Water level: 45  %
# Sufficient water.Irrigation OFF.

# %%
count=1
while True:
  print(count)
  if count==5:
     break
  count+=1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
count=0
while count<5:
  count+=1
  if count==3:
     continue
  print(count)
# Out:
# 1
# 2
# 4
# 5

# %%
count=1
while count<=3:
  print(count)
  count+=1
else:
  print("Loop Completed Successfully")
# Out:
# 1
# 2
# 3
# Loop Completed Successfully
