# %%
#Creating a dictionary
#Dictionaries are written with curly brackets,and have keys and values:

thisdict={
    "Crop":"Rice",
    "Variety":"IR64",
    "Year":"2024"
}

print(thisdict)
# Out:
# {'Crop': 'Rice', 'Variety': 'IR64', 'Year': '2024'}

# %%
thisdict={
    "crop":"cotton",
    "organic":True,
    "year":2024,
    "irrigation_methods":["drip","sprinkler","flood"]
}
print(thisdict)
# Out:
# {'crop': 'cotton', 'organic': True, 'year': 2024, 'irrigation_methods': ['drip', 'sprinkler', 'flood']}

# %%
#type()
thisdict={
    "crop":"Rice",
    "variety":"IR-64",
    "year":"2024"
}
print(type(thisdict))
# Out:
# <class 'dict'>

# %%
thisdict=dict(
    farmer_name="Ramesh",
    age=45,
    village="Mandya"
)
print(thisdict)
# Out:
# {'farmer_name': 'Ramesh', 'age': 45, 'village': 'Mandya'}

# %%
#Add a new item and observe keys update
farm={
    "crop":"Rice",
    "variety":"IR-64",
    "year" : 2022
}
x=farm.keys()
print(x) #before the change

farm["season"]="kharif"
print(x) #after the change
# Out:
# dict_keys(['crop', 'variety', 'year'])
# dict_keys(['crop', 'variety', 'year', 'season'])

# %%
x=thisdict.values()
print(x)

x=farm.values()
print(x) #before the change

farm["year"]=2024
print(x) #after the change
# Out:
# dict_values(['Ramesh', 45, 'Mandya'])
# dict_values(['Rice', 'IR-64', 2024, 'kharif'])
# dict_values(['Rice', 'IR-64', 2024, 'kharif'])

# %%
x=thisdict.items()
print(x)
tuple2=tuple(thisdict.items())
print(tuple2)
print(x)
x_keys=tuple(thisdict.keys())
x_values=list(thisdict.values())
print(x_keys)
print(x_values)
pairs=zip(x_keys,x_values)
print(tuple(pairs))
# Out:
# dict_items([('farmer_name', 'Ramesh'), ('age', 45), ('village', 'Mandya')])
# (('farmer_name', 'Ramesh'), ('age', 45), ('village', 'Mandya'))
# dict_items([('farmer_name', 'Ramesh'), ('age', 45), ('village', 'Mandya')])
# ('farmer_name', 'age', 'village')
# ['Ramesh', 45, 'Mandya']
# (('farmer_name', 'Ramesh'), ('age', 45), ('village', 'Mandya'))

# %%
thisdict={
    "crop":"Rice",
    "variety":"IR-64",
    "year":2022

}
if "variety"in thisdict:
    print("Yes,'variety' is one of the keys in the thisdict dictionary")
# Out:
# Yes,'variety' is one of the keys in the thisdict dictionary

# %%
#Original dictionary
student={
    "name":"Anita",
    "roll_no":101,
    "branch":"CSE",
    "marks":88
}
print("Original dictionary:",student)

#copy()-Creates as shallow copy

student_copy=student.copy()
print("copied dictionary:",student_copy)

#pop()-removes a specific key

removed_value=student.pop("marks")
print("Removed value:",removed_value)
print("After pop():",student)

#popitem()

last_item=student.popitem()
print("Removed value:",last_item)
print("After popitem():",student)

#update

student.update({"year":2,"branch":"AI & DS"})
print("After update():",student)

#clear()

student.clear()
print("After clear():",student)
# Out:
# Original dictionary: {'name': 'Anita', 'roll_no': 101, 'branch': 'CSE', 'marks': 88}
# copied dictionary: {'name': 'Anita', 'roll_no': 101, 'branch': 'CSE', 'marks': 88}
# Removed value: 88
# After pop(): {'name': 'Anita', 'roll_no': 101, 'branch': 'CSE'}
# Removed value: ('branch', 'CSE')
# After popitem(): {'name': 'Anita', 'roll_no': 101}
# After update(): {'name': 'Anita', 'roll_no': 101, 'year': 2, 'branch': 'AI & DS'}
# After clear(): {}

# %%
#assignment:No new container
a={"course":["AI","ML"]}
b=a
print(a is b)
# Out:
# True

# %%
a={"course":["AI","ML"]}
b=a.copy()
print(a is b)
print(a["course"] is b["course"])
# Out:
# False
# True

# %%
squares = {x:x*x for x in range(5)}
print(squares)
# Out:
# {0: 0, 1: 1, 2: 4, 3: 9, 4: 16}

# %%
student={
    "name":"Raj",
    "marks":{"math":90,"cs":95}
}
print(student)
# Out:
# {'name': 'Raj', 'marks': {'math': 90, 'cs': 95}}

# %%
crops=["Rice","Wheat","Maize","Cotton"]

i=0
for crop in crops:
  print("plot",i,"i",crop)
  i +=1
# Out:
# plot 0 i Rice
# plot 1 i Wheat
# plot 2 i Maize
# plot 3 i Cotton

# %%
crops = ["Rice","Wheat","Maize","Cotton"]

for plot_no,crop in enumerate(crops):
  print("Plot",plot_no,":",crop)

# %%
crops=["Rice","Wheat","Maize"]
yields=[1200,1500,1100]

for plot_no,(crop,yield_kg) in enumerate(zip(crops,yields),start=1):
  print(f"plot{plot_no}:{crop}->{yield_kg}kg")
# Out:
# plot1:Rice->1200kg
# plot2:Wheat->1500kg
# plot3:Maize->1100kg

# %%
plot=[1,2,3,4]
crops=["Rice","wheat","Maize","Cotton"]
yields=[1200,1500,1100,900]

for i in range(len(plot)):
  print(plot[i],crops[i],yields[i])
# Out:
# 1 Rice 1200
# 2 wheat 1500
# 3 Maize 1100
# 4 Cotton 900

# %%
plots=[1,2,3,4]
crops=["Rice","Wheat","Maize","Cotton"]
yields=[1200,1500,1100]

for i in range(len(plots)):
  print(plots[i],crops[i],yields[i])
# Out:
# 1 Rice 1200
# 2 Wheat 1500
# 3 Maize 1100
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipython-input-2359915499.py in <cell line: 0>()
#       4
#       5 for i in range(len(plots)):
# ----> 6   print(plots[i],crops[i],yields[i])
#
# IndexError: list index out of range

# %%
plots=[1,2,3,4]
crops=["Rice","wheat","Maize","Cotton"]
yields=[1200,1500,1100,900]

for plot,crop,yield_kg in zip(plots,crops,yields):
  print(f"Plot{plot}grows{crops}with yield{yield_kg}kg")
# Out:
# Plot1grows['Rice', 'wheat', 'Maize', 'Cotton']with yield1200kg
# Plot2grows['Rice', 'wheat', 'Maize', 'Cotton']with yield1500kg
# Plot3grows['Rice', 'wheat', 'Maize', 'Cotton']with yield1100kg
# Plot4grows['Rice', 'wheat', 'Maize', 'Cotton']with yield900kg

# %%
plots=[1,2,3,4]
crops=["Rice","Wheat","Maize","Cotton"]
yields=[1200,1500,1100]

for plot,crop,yield_kg in zip(plots,crops,yields):
  print(f"plot{plot}grows{crop}with yield{yield_kg}")
# Out:
# plot1growsRicewith yield1200kg
# plot2growsWheatwith yield1500kg
# plot3growsMaizewith yield1100kg

# %%
records=[
    (1,"Rice",1200),
    (2,"Wheat",1500),
    (3,"Maize",1100)
]
plot_no,crop,yield_kg=zip(*records)

print(plot_no)
print(crop)
print(yield_kg)
# Out:
# (1, 2, 3)
# ('Rice', 'Wheat', 'Maize')
# (1200, 1500, 1100)

# %%
crop_price={
    "rice":40,
    "wheat":35,
    "maize":30
}

crop_yield={
    "rice":1200,
    "wheat":1500,
    "maize":1100
}
for a,b in zip(crop_price,crop_yield):
  print(a,b)
# Out:
# rice rice
# wheat wheat
# maize maize
