# %%
import numpy as np
rain=[]
for x in range(1,13):
  x=int(input("Enter the rainfall for month{x}:"))
  rain.append(x)
rainfall=np.array(rain)

yld=[]
for y in range(1,13):
  y=float(input(f"Enter yield for month{y}:"))
  yld.append(y)
yields=np.array(yld)

print('===RAINFALL STATISTICS===')
print(f'mean:{np.mean(rainfall):.2f}mm')
print(f'median:{np.median(rainfall):.2f}mm')
print(f'Std dev:{np.std(rainfall):.2f}mm')
print(f'Variance:{np.var(rainfall):.2f}')
print(f'Min:{np.min(rainfall)}mm(Month{np.argmin(rainfall)+1})')
print(f'Max:{np.max(rainfall)}mm(Month{np.argmax(rainfall)+1})')
print(f'Range:{np.ptp(rainfall)}mm')

print('\nYIELD STATISTICS')
print(f'mean:{np.mean(Yields):.2f}tons/ha')
print(f'median:{np.median(Yields):.2f}tons/ha')
print(f'Std Dev:{np.std(Yields):.2f}tons/ha')

print('\n===PERCENTILE===')
percentiles=[25,50,75,90]
rainfall_percentiles=np.percentile(rainfall,percentiles)
for p, val in zip(percentiles,rainfall_percentiles):
    print(f'{p}th percentile rainfall:{val:.2f}mm')

print('\n===CORRELATION ANALYSIS')
correlation_matrix=np.corrcoef(rainfall,Yields)
correlation=correlation_matrix[0,1]
print(f'Rainfall-Yield correlation:{correlation:.4f}')
print('Interpretation:Strong positive correlation'
if correlation>0.7 else'moderate correlation'
if correlation>0.4 else'weak correlation')

print('\n===CUMULATIVE RAINFALL===')
cumulative=np.cumsum(rainfall)
print('Month\tRainfall\tcumulative')
for month,(rain,cum)in enumerate(zip(rainfall,cumulative),1):
  print(f'{month}\t{rain}\t\t{cum}')
# Out:
# Enter the rainfall for month{x}:49
# Enter the rainfall for month{x}:89
# Enter the rainfall for month{x}:7
# Enter the rainfall for month{x}:234
# Enter the rainfall for month{x}:456
# Enter the rainfall for month{x}:600
# Enter the rainfall for month{x}:23
# Enter the rainfall for month{x}:190
# Enter the rainfall for month{x}:560
# Enter the rainfall for month{x}:941
# Enter the rainfall for month{x}:89
# Enter the rainfall for month{x}:90
# Enter yield for month1:2.7
# Enter yield for month2:8.9
# Enter yield for month3:2.0
# Enter yield for month4:3.5
# Enter yield for month5:5.6
# Enter yield for month6:8.9
# Enter yield for month7:23.4
# Enter yield for month8:5.7
# Enter yield for month9:1.6
# Enter yield for month10:2.9
# Enter yield for month11:3.5
# Enter yield for month12:6.0
# ===RAINFALL STATISTICS===
# mean:277.33mm
# median:140.00mm
# Std dev:283.11mm
# Variance:80152.39
# Min:7mm(Month3)
# Max:941mm(Month10)
# Range:934mm
#
# YIELD STATISTICS
# mean:3.82tons/ha
# median:3.35tons/ha
# Std Dev:1.58tons/ha
#
# ===PERCENTILE===
# 25th percentile rainfall:79.00mm
# 50th percentile rainfall:140.00mm
# 75th percentile rainfall:482.00mm
# 90th percentile rainfall:596.00mm
#
# ===CORRELATION ANALYSIS
# Rainfall-Yield correlation:0.2793
# weak correlation
#
# ===CUMULATIVE RAINFALL===
# Month	Rainfall	cumulative
# 1	49		49
# 2	89		138
# 3	7		145
# 4	234		379
# 5	456		835
# 6	600		1435
# 7	23		1458
# 8	190		1648
# 9	560		2208
# 10	941		3149
# 11	89		3238
# 12	90		3328
