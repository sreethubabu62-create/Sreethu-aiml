# %%
def average_yield(yields):
  total=sum(yields)
  return total/len(yields)

crop_yields=[1200,1350,1100,1500]
avg=average_yield(crop_yields)
print("Average yield:",avg)
# Out:
# Average yield: 1287.5

# %%
def increase_yield(yields,increment):
  for i in range(len(yields)):
    yields[i]+=increment

crop_yields=[1200,1350,1100]
increase_yield(crop_yields,100)
print(crop_yields)
# Out:
# [1300, 1450, 1200]

# %%
def convert_to_quintals(yields):
  result=[]
  for value in yields:
    result.append(value/100)
  return result

crop_yields=[1200,1350,1100]
quintals=convert_to_quintals(crop_yields)
print(quintals)
# Out:
# [12.0, 13.5, 11.0]

# %%
def high_yield_crops(yields,threshold):
  high=[]
  for value in yields:
    if value>=threshold:
      high.append(value)
  return high

crop_yields=[1200,900,1500,800]
print(high_yield_crops(crop_yields,1000))
# Out:
# [1200, 1500]

# %%
def sort_prices(prices):
  prices.sort()
  return prices

crop_prices=[1800,1500,2200,2000]
print(sort_prices(crop_prices))
# Out:
# [1500, 1800, 2000, 2200]

# %%
def sort_prices(prices):
   prices.sort()
   crop_prices_sorted=sorted(prices)
   return crop_prices_sorted

crop_prices=[1800,1500,2200,2000]
list1=sort_prices(crop_prices)
print(list1)
# Out:
# [1500, 1800, 2000, 2200]

# %%
def collect_yields():
  yields=[]
  n=int(input("Enter number of fields:"))
  for i in range(n):
    value=int(input("Enter yield:"))
    yields.append(values)
  return yields
data=collect_yields()
print("Collected yields:",data)
# Out:
# Enter number of fields:2
# Enter yield:3
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1777375159.py in <cell line: 0>()
#       6     yields.append(values)
#       7   return yields
# ----> 8 data=collect_yields()
#       9 print("Collected yields:",data)
#
# /tmp/ipython-input-1777375159.py in collect_yields()
#       4   for i in range(n):
#       5     value=int(input("Enter yield:"))
# ----> 6     yields.append(values)
#       7   return yields
#       8 data=collect_yields()
#
# NameError: name 'values' is not defined

# %%
def yield_statistics(yields):
  print("Maximum yield:",max(yields))
  print("Minimum yield:",min(yields))
  print("Total fields:",len(yields))
crop_yields=[1200,1350,1100]
yield_statistics(crop_yields)
# Out:
# Maximum yield: 1350
# Minimum yield: 1100
# Total fields: 3

# %%
def get_yields():
    n = int(input("Enter number of fields "))
    yields = []
    for i in range(n):
        y = float(input(f"Yield for field {i+1} (kg): "))
        yields.append(y)
    return yields

def show_yields(yields):
    print("All yields:")
    for i, y in enumerate(yields):
        print(f"Field {i+1}: {y} kg")

def avg_yield(yields):
    total=sum(yields)
    return sum(yields) / len(yields)
crop_yields=[200,300,400,1000]
avg=avg_yield(crop_yields)
print("Average yield:",avg)

def above_threshold(yields, thresh):
  above=[]
  for value in yields:
    if value>=thresh:
      above.append(value)
  return [above]
crop_yields=[200,300,400,1000]
print(above_threshold(crop_yields,1100))

def yield_statistics(yields):
  print(f"\nTotal fields: {len(yields)}")
  print(f"Max yield: {max(yields)} kg")
  print(f"Min yield: {min(yields)} kg")
  print(f"Average yield: {avg_yield(yields)} kg")

# Call the yield_statistics function to display the statistics
crop_yields=[200,300,400,1000] # Ensure crop_yields is defined before calling
yield_statistics(crop_yields)
# Out:
# Average yield: 475.0
# [[]]
#
# Total fields: 4
# Max yield: 1000 kg
# Min yield: 200 kg
# Average yield: 475.0 kg
